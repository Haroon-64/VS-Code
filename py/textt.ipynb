# %%
from newsapi import NewsApiClient
import pandas as pd

# %%
api = NewsApiClient(api_key='6fc6701c20e24b4399c04d8033517c8e')

# %%
n = api.get_everything(q='gaza', language='en', page_size=10, sort_by='relevancy')

# %%
n
# Out:
# {'status': 'ok',
#  'totalResults': 19476,
#  'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "Ben Wallace warns Israel over 'killing rage' in Gaza",
#    'description': 'The former UK defence secretary says Israel risks undermining its legal basis for actions in Gaza.',
#    'url': 'https://www.bbc.co.uk/news/uk-67745408',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/FC41/production/_132077546_c3ad343ba56db631962910bb1168614f5144af580_0_5500_36671000x667.jpg',
#    'publishedAt': '2023-12-18T07:40:12Z',
#    'content': 'Israel risks fuelling its conflict for another 50 years with their tactics in Gaza, former defence secretary Ben Wallace has warned.\r\nWriting in the Daily Telegraph, the senior Conservative MP said I… [+3003 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
# ...

# %%
d = pd.DataFrame(n['articles'])

# %%
d
# Out:
#                                    source                            author  \
# 0  {'id': 'bbc-news', 'name': 'BBC News'}  https://www.facebook.com/bbcnews
# 1  {'id': 'bbc-news', 'name': 'BBC News'}  https://www.facebook.com/bbcnews
# 2  {'id': 'bbc-news', 'name': 'BBC News'}  https://www.facebook.com/bbcnews
# 3  {'id': 'bbc-news', 'name': 'BBC News'}  https://www.facebook.com/bbcnews
# 4  {'id': 'bbc-news', 'name': 'BBC News'}  https://www.facebook.com/bbcnews
# 5  {'id': 'bbc-news', 'name': 'BBC News'}  https://www.facebook.com/bbcnews
# 6  {'id': 'bbc-news', 'name': 'BBC News'}  https://www.facebook.com/bbcnews
# 7  {'id': 'bbc-news', 'name': 'BBC News'}  https://www.facebook.com/bbcnews
# 8  {'id': 'engadget', 'name': 'Engadget'}                     Mariella Moon
# 9  {'id': 'bbc-news', 'name': 'BBC News'}  https://www.facebook.com/bbcnews
#
#                                                title  \
# 0  Ben Wallace warns Israel over 'killing rage' i...
# ...

# %%
import numpy as np
x = np.array([1,2,3])
y= np.array([[1],[2],[3]])
x+y
# Out:
# array([[2, 3, 4],
#        [3, 4, 5],
#        [4, 5, 6]])
